# %% [markdown]
# # Python Practice: Tuple and Set (Practice Only)
#
# This notebook contains **practice questions only** on **Tuples** and **Sets**.
#
# Instructions:
# - Questions are written in **text cells**
# - Write your solution in the **code cell below each question**
# - Do NOT use any advanced concepts

# %% [markdown]
# ##  Tuple Practice Questions

# %% [markdown]
# ### Question 1
# Create a tuple of 5 integers and print it.

# %%
# write your answer here
t=(1,2,3,4,5)
print(t)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### Question 2
# Create a tuple with different data types (int, float, string, boolean) and print each element separately.

# %%
# write your answer here
t=(1,3.4,"hello", True)
for i in t:
  print(i)
# Out:
# 1
# 3.4
# hello
# True

# %% [markdown]
# ### Question 3
# Find the length of a tuple containing names of 4 students.

# %%
# write your answer here
name =("kritvi", "mithi","prajjwal","amrit")
print(len(name))
# Out:
# 4

# %% [markdown]
# ### Question 4
# Access and print the last element of a tuple.

# %%
# write your answer here
name =("kritvi", "mithi","prajjwal","amrit")
print(name[-1])
# Out:
# amrit

# %% [markdown]
# ### Question 5
# Check whether an element exists in a tuple or not.

# %%
# write your answer here
my_tuple=("kritvi", "mithi","prajjwal","amrit")
if "mithi" in my_tuple:
  print("elements exists")

else:
  print("element does not exist")
# Out:
# elements exists

# %% [markdown]
# ### Question 6
# Convert a tuple into a list.

# %%
# write your answer here
my_tuple=("kritvi", "mithi","prajjwal","amrit")
my_list =list(my_tuple)
print(my_list)
# Out:
# ['kritvi', 'mithi', 'prajjwal', 'amrit']

# %% [markdown]
# ### Question 7
# Convert a list into a tuple.

# %%
# write your answer here
my_list =["kritvi", "mithi","prajjwal","amrit"]
my_tuple = tuple(my_list)
print(my_tuple)
# Out:
# ('kritvi', 'mithi', 'prajjwal', 'amrit')

# %% [markdown]
# ### Question 8
# Create a tuple with repeated values and count how many times an element appears.

# %%
# write your answer here

t=("apple", "banana", "cherry", "apple", "cherry")

s=[]  #apple , banana #cherry


for i in t:
  if i not in s:
    print(f"this is count of {i}",t.count(i))
    s.append(i)
# Out:
# this is count of apple 2
# this is count of banana 1
# this is count of cherry 2

# %% [markdown]
# ### Question 9
# Find the index of an element in a tuple.

# %%
# write your answer here
t=(10,20,30,40,50)
index= t.index(30)
print("index of 30 is:", index)
# Out:
# index of 30 is: 2

# %% [markdown]
# ### Question 10
# Demonstrate that tuples are immutable (cannot be changed).

# %%
# write your answer here
t=("apple", "banana", "cherry", "apple", "cherry")

print(t[3])

t[3]="guava"     # this line will throw error and hence tuple is immutable

print(t)

# %%
tup=(1,2,)

tu=1,3,4


list1=[7,9]

tup_Fin=tuple(list1)

print(type(tup_Fin),tup_Fin)


l1=list(tup_Fin)

print(type(l1),l1)
# Out:
# <class 'tuple'> (7, 9)
# <class 'list'> [7, 9]

# %%
marks_of_student=(12,16,19,9,8)

c=sorted(marks_of_student)
c[-2:]
# Out:
# [16, 19]

# %%
print(t)

new=set(t)

l1=list(t)


print(new)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')
# {'cherry', 'banana', 'apple'}

# %%
s1= {1,2,1,56,8,436,8}

s2={}

print(type(s2))

print(s2)
# Out:
# <class 'dict'>
# {}
